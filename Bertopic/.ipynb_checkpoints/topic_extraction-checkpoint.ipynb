# %%
from bertopic import BERTopic
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_20newsgroups

# %%
# import data
data_df = pd.read_csv('C:\\Users\\gcmar\\Desktop\\GIT_REPOS\\LAB\\Literature_summary\\Papers\\scopus_bark_ambrosia_beetles.csv')
data_df['text'] = data_df['Title'].apply(str) + data_df['Author Keywords'].apply(str) + data_df['Index Keywords'].apply(str) + data_df['Abstract'].apply(str) 
data_df['topic_text'] = data_df['Title'].apply(str) + data_df['Author Keywords'].apply(str) + data_df['Index Keywords'].apply(str)
docs = data_df['text'].dropna().tolist()
topic_docs = data_df['topic_text'].dropna().tolist()

# %%
model = BERTopic(embedding_model="all-mpnet-base-v2", nr_topics="auto", top_n_words=15) #"xlm-r-bert-base-nli-stsb-mean-tokens"

# %% [markdown]
# #### Topics per doc

# %%
topics, probabilities = model.fit_transform(docs)

# %%
data_df['topic'] = topics
data_df['topic_prob'] = probabilities.tolist()

# add topic words column
topic_df = pd.DataFrame(np.array(list(model.topic_representations_.values()))[:,:,0])
topic_df['topic_words'] = topic_df[topic_df.columns].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
topic_df['topic'] = list(model.topic_representations_)
topic_df['topic_words'][0] = None
topic_df = topic_df[['topic', 'topic_words']]
data_df.merge(topic_df,how='left', on='topic')
# Out:
#       Unnamed: 0                                            Authors  \
# 0              0  Dos-Santos C.A.A., Trevisan H., De-Carvalho A....
# 1              1             Oliveira A.G., Silva M.H.M., Garlet J.
# 2              2  Liu Z., Xing L., Huang W., Liu B., Wan F., Raf...
# 3              3  Cui P., Kong K., Yao Y., Huang Z., Shi S., Liu...
# 4              4             Luo F., Meng L.-Z., Wang J., Liu Y.-H.
# ...          ...                                                ...
# 3672        1691  Scully E.D., Hoover K., Carlson J.E., Tien M.,...
# 3673        1692  Popa V., Morneau L., Piché C., Deshaies A., Ba...
# 3674        1693  Bousquet Y., Bouchard P., Davies A.E., Sikes D.S.
# 3675        1694  Gitau C.W., Carnegie A.J., Nicol H.I., Bashfor...
# 3676        1695         Jordal B.H., Gebhardt H., Mandelshtam M.Y.
#
#                                            Author(s) ID  \
# 0     57736986800;55534398100;7102272203;55743907500...
# 1                  57225032457;57221317874;26641043600;
# 2     15029915900;57217564509;57856128300;5720296431...
# 3     57766827100;57766581800;57766869900;5776674380...
# 4      57209534340;41861872600;56998326000;53867940300;
# ...                                                 ...
# 3672  55177982500;7005286497;7402114949;7006146774;2...
# 3673  55204663000;35726926800;6602096109;55943191100...
# 3674      6603678494;7102856272;12244861500;7003547705;
# 3675  55899133800;57222968421;24402150300;6603484985...
# 3676                6602995438;55971052200;55399557400;
#
#                                                   Title  Year  \
# 0     Increased capture efficiency of Scolytinae wit...  2024
# 1     Coleoborers in Bambusa sp. in the Southern Ama...  2023
# 2     Chromosome-level genome assembly and populatio...  2022
# 3     Community composition, bacterial symbionts, an...  2022
# 4     The patterns of co-occurrence variation are ex...  2022
# ...                                                 ...   ...
# 3672  Midgut transcriptome profiling of Anoplophora ...  2013
# 3673  Occurrence of species of the genus Pityophthor...  2013
# 3674  Checklist of beetles (Coleoptera) of Canada an...  2013
# 3675  Incidence of Ips grandicollis (Coleoptera: Sco...  2013
# 3676  The red-listed species thamnurgus rossicus in ...  2013
#
#                        Source title Volume Issue Art. No. Page start  ...  \
# 0      Brazilian Journal of Biology     84   NaN  e259131        NaN  ...
# 1      Brazilian Journal of Biology     83   NaN  e237813        NaN  ...
# 2                       BMC Biology     20     1      190        NaN  ...
# 3                  BMC Microbiology     22     1      168        NaN  ...
# 4              Frontiers in Zoology     19     1       10        NaN  ...
# ...                             ...    ...   ...      ...        ...  ...
# 3672                   BMC Genomics     14     1      850        NaN  ...
# 3673                        ZooKeys    348   NaN      NaN         97  ...
# 3674                        ZooKeys    360   NaN      NaN          1  ...
# 3675  Forest Ecology and Management    310   NaN      NaN        865  ...
# 3676                        Zootaxa   3750     1      NaN         83  ...
#
#      Document Type  Publication Stage                   Open Access  Source  \
# 0          Article              Final         All Open Access, Gold  Scopus
# 1          Article              Final         All Open Access, Gold  Scopus
# 2          Article              Final  All Open Access, Gold, Green  Scopus
# 3          Article              Final  All Open Access, Gold, Green  Scopus
# 4          Article              Final  All Open Access, Gold, Green  Scopus
# ...            ...                ...                           ...     ...
# 3672       Article              Final  All Open Access, Gold, Green  Scopus
# 3673       Article              Final  All Open Access, Gold, Green  Scopus
# 3674       Article              Final  All Open Access, Gold, Green  Scopus
# 3675       Article              Final                           NaN  Scopus
# 3676       Article              Final                           NaN  Scopus
#
#                      EID                                               text  \
# 0     2-s2.0-85131771541  Increased capture efficiency of Scolytinae wit...
# 1     2-s2.0-85109044350  Coleoborers in Bambusa sp. in the Southern Ama...
# 2     2-s2.0-85136521758  Chromosome-level genome assembly and populatio...
# 3     2-s2.0-85132963524  Community composition, bacterial symbionts, an...
# 4     2-s2.0-85126256734  The patterns of co-occurrence variation are ex...
# ...                  ...                                                ...
# 3672  2-s2.0-84888778656  Midgut transcriptome profiling of Anoplophora ...
# 3673  2-s2.0-84888621460  Occurrence of species of the genus Pityophthor...
# 3674  2-s2.0-84889843393  Checklist of beetles (Coleoptera) of Canada an...
# 3675  2-s2.0-84888128611  Incidence of Ips grandicollis (Coleoptera: Sco...
# 3676  2-s2.0-84890622287  The red-listed species thamnurgus rossicus in ...
#
#                                              topic_text topic topic_prob  \
# 0     Increased capture efficiency of Scolytinae wit...    -1   0.000000
# 1     Coleoborers in Bambusa sp. in the Southern Ama...     1   1.000000
# 2     Chromosome-level genome assembly and populatio...    -1   0.000000
# 3     Community composition, bacterial symbionts, an...     5   0.892907
# 4     The patterns of co-occurrence variation are ex...     6   0.230674
# ...                                                 ...   ...        ...
# 3672  Midgut transcriptome profiling of Anoplophora ...     5   1.000000
# 3673  Occurrence of species of the genus Pityophthor...    -1   0.000000
# 3674  Checklist of beetles (Coleoptera) of Canada an...    -1   0.000000
# 3675  Incidence of Ips grandicollis (Coleoptera: Sco...     1   0.769488
# 3676  The red-listed species thamnurgus rossicus in ...     7   0.611384
#
#                                             topic_words
# 0                                                  None
# 1     and of the species to in forest for invasive n...
# 2                                                  None
# 3     bacterial bacteria gut microbial the of insect...
# 4     saproxylic forest species dead wood in richnes...
# ...                                                 ...
# 3672  bacterial bacteria gut microbial the of insect...
# 3673                                               None
# 3674                                               None
# 3675  and of the species to in forest for invasive n...
# 3676  dna mitochondrial molecular of the species and...
#
# [3677 rows x 60 columns]

# %%
data_df.to_csv('papers_bertopic.csv', index=False)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                            Name
# 0      -1   1109                                -1_the_of_and_in
# 1       0    577                                 0_of_and_the_in
# 2       1    345                            1_and_of_the_species
# 3       2    281                   2_fungi_ophiostoma_fungal_the
# 4       3    121                    3_social_females_care_mating
# 5       4    113             4_pine_pinus_dendroctonus_mortality
# 6       5    108              5_bacterial_bacteria_gut_microbial
# 7       6     88                6_saproxylic_forest_species_dead
# 8       7     80                7_dna_mitochondrial_molecular_of
# 9       8     51              8_walnut_juglans_juglandis_morbida
# 10      9     47                       9_wood_ash_treatment_heat
# 11     10     43                        10_europe_in_species_the
# 12     11     41           11_sensilla_antennal_types_basiconica
# 13     12     38             12_coffee_hampei_hypothenemus_berry
# 14     13     34              13_fossil_amber_cretaceous_legalov
# 15     14     32       14_cold_temperature_diapause_temperatures
# 16     15     29     15_pheromone_frontalin_ipsdienol_brevicomin
# 17     16     29             16_pheromone_males_aggregation_male
# 18     17     27                17_climate_forest_outbreaks_bark
# 19     18     27        18_synthesis_pheromones_chiral_pheromone
# 20     19     27                         19_fungi_genera_dna_and
# 21     20     26                 20_mycangia_mycangium_the_micro
# 22     21     25                  21_yeast_candida_yeasts_pichia
# 23     22     24  22_genetic_populations_dendroctonus_population
# 24     23     24              23_islands_hawaiian_endemic_island
# 25     24     24     24_mango_mangiferae_hypocryphalus_mangifera
# 26     25     23        25_bursaphelenchus_nematode_nematodes_sp
# 27     26     23                 26_remote_sensing_fire_unmanned
# 28     27     22               27_fire_mortality_crown_ponderosa
# 29     28     22         28_geosmithia_species_hypocreales_fungi
# 30     29     21             29_insects_insect_ecosystem_ecology
# 31     30     17            30_ethanol_concentrations_root_trees
# 32     31     17          31_verbenone_dendroctonus_douglas_pine
# 33     32     17                32_acoustic_female_sounds_chirps
# 34     33     16              33_volatile_organic_vocs_compounds
# 35     34     16                   34_shot_hole_california_borer
# 36     35     15                          35_elm_ulmi_dutch_novo
# 37     36     14                  36_mite_mites_phoretic_phoresy
# 38     37     14                        37_pest_pull_insect_push
# 39     38     14                  38_lake_fossil_pollen_holocene
# 40     39     13              39_receptor_olfactory_neurons_orns
# 41     40     11           40_pityol_conophthorus_coniperda_cone
# 42     41     11             41_pitch_canker_monterey_circinatum
# 43     42     11          42_wolbachia_wsp_infected_endosymbiont
# 44     43     10          43_carbaryl_bifenthrin_insecticides_06

# %%
fig = model.visualize_topics()
fig.write_html("topics_viz.html")

# %% [markdown]
# #### Topics over time

# %%
topics_over_time = model.topics_over_time(docs, timestamps=data_df['Year'].tolist())

# %%
fig = model.visualize_topics_over_time(topics_over_time)
fig.write_html("topics_over_time.html")

# %% [markdown]
# #### Multiple topics

# %%
model = BERTopic(embedding_model="all-mpnet-base-v2", nr_topics="auto", top_n_words=5) #"xlm-r-bert-base-nli-stsb-mean-tokens"

# %%
num_repeats = 5
for i in range(num_repeats):
    topics, probabilities = model.fit_transform(docs)
    data_df['topic_'+str(i)] = topics
    data_df['topic_prob_'+str(i)] = probabilities.tolist()

    # add topic words column
    topic_df = pd.DataFrame(np.array(list(model.topic_representations_.values()))[:,:,0])
    topic_df['topic_words_'+str(i)] = topic_df[topic_df.columns].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
    topic_df['topic'] = list(model.topic_representations_)
    topic_df['topic_words_'+str(i)][0] = None
    topic_df = topic_df[['topic', 'topic_words_'+str(i)]]
    data_df = data_df.merge(topic_df,how='left', left_on='topic_'+str(i), right_on='topic')

# %%
data_df.to_csv('papers_bertopics_multi.csv', index=False)
